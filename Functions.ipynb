# %%
import numpy 
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.special import logsumexp

# %%
g_big = 6.67430E-11 #N m^2 kg^-2
m_sol = 1.98847E30 #kg
c = 3E8 #m s^-1
sigma = 5.670374419E-8 #W m^-2 K^-4
h = 6.62607015E-34 
k = 1.380649E-23 

m     = 10*m_sol
m_dot = 10.0E5  #kg s^-1
r_g   = g_big*m/c**2
r_in = 6 
r_out = 10.0E5
nu = 7.0E5

# %%
r = numpy.linspace(r_in, r_out, num=3)

temps = T(r)

print(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [180], in <cell line: 5>()
#       1 r = numpy.linspace(r_in, r_out, num=3)
#       3 temps = T(r)
# ----> 5 print(r)
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
def T(rad):
    return (((3*g_big*m*m_dot)/(8*numpy.pi*rad**3*r_g**3*sigma))*(1-numpy.sqrt(r_in/rad)))**0.25

# %%
def F_nu(temp):
    return ((2*numpy.pi*h*nu**3)/c**2)/(numpy.exp((h*nu)/(k*temp))-1)

# %%
r = numpy.linspace(r_in, r_out, num=3)

temps = T(r)

print(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [176], in <cell line: 5>()
#       1 r= numpy.linspace(r_in, r_out, num=3)
#       3 temps = T(r)
# ----> 5 print(r)
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
figure=plt.figure(figsize=(15,8))

ax.patch.set_linewidth('1') 
plt.plot(r,temps, label='n=0')

plt.xlabel('$r$')
plt.ylabel('$T$')
plt.yscale("log")

# %%
freq = F_nu(temps)
print(freq)
# Out:
# /var/folders/xs/gwr782hx4v521vx983pq0n180000gn/T/ipykernel_90447/1476414392.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   return ((2*numpy.pi*h*nu**3)/c**2)/(numpy.exp((h*nu)/(k*temp))-1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [138], in <cell line: 2>()
#       1 freq = F_nu(temps)
# ----> 2 print(freq)
#
# ValueError: maximum supported dimension for an ndarray is 32, found 50000

# %%
figure=plt.figure(figsize=(15,8))

ax.patch.set_linewidth('1') 
plt.plot(temps,freq, label='n=0')

plt.xlabel('$T$')
plt.ylabel('$F$')
plt.yscale("log")

# %%
def integrand(x, F):
    return F*4*numpy.pi*r_g**2*x

from scipy.integrate import quad

F=freq
L_nu=[]

for i in F:
    L_nui = quad(integrand, r_in, r_out, args=(i))
    L_nu.append(L_nui)

# %%
print(L_nu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [133], in <cell line: 1>()
# ----> 1 print(L_nu)
#
# ValueError: maximum supported dimension for an ndarray is 32, found 50000
